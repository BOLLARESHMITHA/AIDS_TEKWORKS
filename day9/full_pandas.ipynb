# %%
import numpy as np
import pandas as pd

# %%
pd.Series([80,97,98,100],name="marks")
pd.Series(["alice","bob","mic","roy"],name="names")
# Out:
# 0    alice
# 1      bob
# 2      mic
# 3      roy
# Name: names, dtype: object

# %%
sample=pd.Series(data=[1,2,3,4,5],index=['1st','2nd','3rd','4th','5th'],name="sample")
print(sample['1st'])
print(sample+5)
# Out:
# 1
# 1st     6
# 2nd     7
# 3rd     8
# 4th     9
# 5th    10
# Name: sample, dtype: int64

# %% [markdown]
# Using **Pandas Series**, perform the following:
#
# ✅ Create a Series named `scores` using the dictionary `student_scores`.
#
# ✅ Print the marks scored by **"Charlie"** and **"Eva"**.
#
# ✅ Add **5 bonus marks** to all students and print the updated Series.
#
# ✅ Display only the students who scored **above 90** after the bonus.
#
# ✅ Calculate and print the **average marks** of the class (after the bonus).

# %%
student_scores={'charlie':90,'eva':89,'alice':99,'bob':85}
scores=pd.Series(data=student_scores,name="scores")
print("score of charlie = ",scores['charlie']," and eva = ",scores['eva'])
scores=scores+5
print("updated Series after Added 5 bonus marks to all students =\n",scores)
print("students who scored above 90 after the bonus =\n",scores[scores>90])
print("average marks of the class (after the bonus) = ",np.average(scores))
# Out:
# score of charlie =  90  and eva =  89
# updated Series after Added 5 bonus marks to all students =
#  charlie     95
# eva         94
# alice      104
# bob         90
# Name: scores, dtype: int64
# students who scored above 90 after the bonus =
#  charlie     95
# eva         94
# alice      104
# Name: scores, dtype: int64
# average marks of the class (after the bonus) =  95.75

# %%
age_mark=np.array([[25,85],[25,90],[26,70],[24,80]])
std_data=pd.DataFrame(data=age_mark,index=['ravali','mihra','siva','micky'],columns=['age','marks'])
print(std_data)
# Out:
#         age  marks
# ravali   25     85
# mihra    25     90
# siva     26     70
# micky    24     80

# %%
print(std_data.values)
std_data.index
std_data.columns
# Out:
# [[25 85]
#  [25 90]
#  [26 70]
#  [24 80]]
# Index(['age', 'marks'], dtype='object')

# %%
d_std={'name':{'ra':'ravali','mi':'mihra','si':'siva','mic':'micky'},
       'age':{'ra':25,'mi':25,'si':26,'mic':24},
       'marks':{'ra':85,'mi':90,'si':70,'mic':80}}
d_std_data=pd.DataFrame(data=d_std)
print(d_std_data)
d_std['name']
# Out:
#        name  age  marks
# ra   ravali   25     85
# mi    mihra   25     90
# si     siva   26     70
# mic   micky   24     80
# {'ra': 'ravali', 'mi': 'mihra', 'si': 'siva', 'mic': 'micky'}

# %%
print(type(std_data.index))
print(type(std_data.values))
print(type(std_data.columns))
print(std_data.values.ndim)
print(std_data.values.shape)
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'numpy.ndarray'>
# <class 'pandas.core.indexes.base.Index'>
# 2
# (4, 2)

# %%
s_names=pd.Series(data=['ravali','mihra','siva','micky'],index=['ra','mi','si','mic'])
s_age=pd.Series(data=[25,25,26,24],index=['ra','mi','si','mic'])
s_marks=pd.Series(data=[85,90,70,80],index=['ra','mi','si','mic'])
s_dict={'names':s_names,'age':s_age,'marks':s_marks}
s_std_data=pd.DataFrame(s_dict)
print(s_std_data)
# Out:
#       names  age  marks
# ra   ravali   25     85
# mi    mihra   25     90
# si     siva   26     70
# mic   micky   24     80

# %% [markdown]
# You are given three Series representing student data:
#
# Names of students
#
# Their ages
#
# Their marks
#
# These series are combined into a DataFrame as shown earlier.
#
# ### 🎯 Your Task:
# Using the existing DataFrame, perform the following operations:
#
# ✅ Print the details (name, age, marks) of the student who scored the highest marks.
#
# ✅ Add a new student "Tharushi" with age 23 and marks 88 using the index "Th".
#
# ✅ Display the details of students who are 25 years old or older.
#
# ✅ Increase the marks of students below 80 by 10 bonus points.
#
# ✅ Calculate and print the average marks of all students after the bonus.

# %%
# Top student
top_std = np.array(s_std_data.values[s_std_data.marks == np.max(s_std_data.marks)])
print("Top student -> name = ", top_std[0,0], " age = ", top_std[0,1], " marks = ", top_std[0,2])

# Students 25 or older
print("\nDetails of students who are 25 years old or older:\n", s_std_data[s_std_data.age >= 25].values)

# Add bonus 10 marks for students with marks < 80
s_std_data.loc[s_std_data.marks < 80, 'marks'] += 10

# Show updated student data
print("\nUpdated student data with bonus marks:\n", s_std_data.values)

# Average marks after bonus
print("\nAverage marks of all students after the bonus = ", np.mean(s_std_data.marks))
# Out:
# Top student -> name =  mihra  age =  25  marks =  90
#
# Details of students who are 25 years old or older:
#  [['ravali' 25 85]
#  ['mihra' 25 90]
#  ['siva' 26 70]]
#
# Updated student data with bonus marks:
#  [['ravali' 25 85]
#  ['mihra' 25 90]
#  ['siva' 26 80]
#  ['micky' 24 80]]
#
# Average marks of all students after the bonus =  83.75

# %%
from google.colab import drive
drive.mount('/content/drive')
path='/content/drive/My Drive/Colab Notebooks/data.csv'
df=pd.read_csv(path)
print(df.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01    110       130     409.1
# 1        60  2020/12/02    117       145     479.0
# 2        60  2020/12/03    103       135     340.0
# 3        45  2020/12/04    109       175     282.4
# 4        45  2020/12/05    117       148     406.0

# %%
print(df.info)
print(df[df['Calories']>400])
print(df[df['Date'].isnull()])
print(df[df['Calories'].isnull()])
# Out:
# <bound method DataFrame.info of     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# ...

# %%
new_df=df.dropna()
print(new_df)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
print(new_df.to_string())
#print(type(new_df.to_string()))
df.fillna(130,inplace=True)
print(df)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
x=df['Calories'].mode()
df.fillna({"Calories":x},inplace=True)
print(df,x)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
df['Date']=pd.to_datetime(df['Date'],format='mixed')
print(df.to_string())
df.dropna(subset=['Date'],inplace=True)
df
# Out:
#     Duration                          Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0
# 3         45 2020-12-04 00:00:00.000000000    109       175     282.4
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0
# 5         60 2020-12-06 00:00:00.000000000    102       127     300.0
# 6         60 2020-12-07 00:00:00.000000000    110       136     374.0
# 7        450 2020-12-08 00:00:00.000000000    104       134     253.3
# 8         30 2020-12-09 00:00:00.000000000    109       133     195.1
# 9         60 2020-12-10 00:00:00.000000000     98       124     269.0
# 10        60 2020-12-11 00:00:00.000000000    103       147     329.3
# 11        60 2020-12-12 00:00:00.000000000    100       120     250.7
# ...

# %%
y = df['Duration'].mean()
print("Mean Duration:", y)

# Filter rows where Duration > 60
filtered = df[df['Duration'] > 60]
print("\nRows with Duration > 60:\n", filtered)

# Check if any Duration in filtered rows is > 120
if (filtered['Duration'] > 120).any():
    print("\nThere is at least one row with Duration > 120")
else:
    print("\nNo row has Duration > 120")
# Out:
# Mean Duration: 68.4375
#
# Rows with Duration > 60:
#     Duration       Date  Pulse  Maxpulse  Calories
# 7       450 2020-12-08    104       134     253.3
#
# There is at least one row with Duration > 120

# %%
for x in df.index:
  if df.loc[x,'Duration']>120:
    df.drop(x,inplace=True)
df
# Out:
#     Duration                          Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0
# 3         45 2020-12-04 00:00:00.000000000    109       175     282.4
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0
# 5         60 2020-12-06 00:00:00.000000000    102       127     300.0
# 6         60 2020-12-07 00:00:00.000000000    110       136     374.0
# 8         30 2020-12-09 00:00:00.000000000    109       133     195.1
# 9         60 2020-12-10 00:00:00.000000000     98       124     269.0
# 10        60 2020-12-11 00:00:00.000000000    103       147     329.3
# 11        60 2020-12-12 00:00:00.000000000    100       120     250.7
# 12        60 2020-12-12 00:00:00.000000000    100       120     250.7
# ...

# %%
print(df.duplicated())
df.drop_duplicates(inplace=True)
df
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool
#     Duration                          Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0
# 3         45 2020-12-04 00:00:00.000000000    109       175     282.4
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0
# 5         60 2020-12-06 00:00:00.000000000    102       127     300.0
# ...

# %%
high_pulse=df[df['Pulse']>110]
print(high_pulse)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 1         60 2020-12-02    117       145     479.0
# 4         45 2020-12-05    117       148     406.0
# 23        60 2020-12-23    130       101     300.0

# %%
sorted_df=df.sort_values(by='Calories',ascending=False)
sorted_df
# Out:
#     Duration                          Date  Pulse  Maxpulse  Calories
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0
# 30        60 2020-12-30 00:00:00.000000000    102       129     380.3
# 14        60 2020-12-14 00:00:00.000000000    104       132     379.3
# 6         60 2020-12-07 00:00:00.000000000    110       136     374.0
# 21        60 2020-12-21 00:00:00.000000000    108       131     364.2
# 13        60 2020-12-13 00:00:00.000000000    106       128     345.3
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0
# 25        60 2020-12-25 00:00:00.000000000    102       126     334.5
# 10        60 2020-12-11 00:00:00.000000000    103       147     329.3
# 19        60 2020-12-19 00:00:00.000000000    103       123     323.0
# ...

# %% [markdown]
# # Create another DataFrame with Date and Trainer name
# trainer_df = pd.DataFrame({
#     'Date': ['2020/12/01', '2020/12/02', '2020/12/03'],
#     'Trainer': ['Alex', 'Jordan', 'Taylor']
# })
#
# # Convert 'Date' column in trainer_df to datetime format
# trainer_df['Date'] = pd.to_datetime(trainer_df['Date'])
#
# # Now merge
# merged_df = pd.merge(df, trainer_df, on='Date', how='left')
#
# print(merged_df)

# %%
trainer_df = pd.DataFrame({
    'Date': ['2020/12/01', '2020/12/02', '2020/12/03'],
    'Trainer': ['Alex', 'Jordan', 'Taylor']
})

# Convert both to datetime
df['Date'] = pd.to_datetime(df['Date']).dt.date
trainer_df['Date'] = pd.to_datetime(trainer_df['Date']).dt.date

# Merge on Date
merged_df = pd.merge(df, trainer_df, on='Date', how='left')

print("Merged DataFrame:\n", merged_df)

# Now you can safely count trainers
print("\nTrainer counts:\n", merged_df['Trainer'].value_counts())
# Out:
# Merged DataFrame:
#      Duration        Date  Pulse  Maxpulse  Calories Trainer
# 0         60  2020-12-01    110       130     409.1    Alex
# 1         60  2020-12-02    117       145     479.0  Jordan
# 2         60  2020-12-03    103       135     340.0  Taylor
# 3         45  2020-12-04    109       175     282.4     NaN
# 4         45  2020-12-05    117       148     406.0     NaN
# 5         60  2020-12-06    102       127     300.0     NaN
# 6         60  2020-12-07    110       136     374.0     NaN
# 7         30  2020-12-09    109       133     195.1     NaN
# 8         60  2020-12-10     98       124     269.0     NaN
# 9         60  2020-12-11    103       147     329.3     NaN
# 10        60  2020-12-12    100       120     250.7     NaN
# 11        60  2020-12-13    106       128     345.3     NaN
# 12        60  2020-12-14    104       132     379.3     NaN
# 13        60  2020-12-15     98       123     275.0     NaN
# ...

# %%
## Group by Duration and Calculate Average Calories
### Groups the dataset by the Duration column (i.e., how long each activity lasted).
### For each unique Duration, it computes the average Calories burned.
### Returns a Series with Duration as the index and average Calories as values.


# Group by Duration and get average Calories
avg_calories_by_duration = df.groupby('Duration')['Calories'].mean()

# Group by Pulse range (bucketed)
df['PulseRange'] = pd.cut(df['Pulse'], bins=[100, 110, 120, 130, 140, 150, 180])
grouped_stats = df.groupby('PulseRange', observed=False).agg({
    'Calories': 'mean',
    'Maxpulse': 'max'
})

print(grouped_stats)
df
# Out:
#             Calories  Maxpulse
# PulseRange
# (100, 110]     315.5     175.0
# (110, 120]     442.5     148.0
# (120, 130]     300.0     101.0
# (130, 140]       NaN       NaN
# (140, 150]       NaN       NaN
# (150, 180]       NaN       NaN
#     Duration        Date  Pulse  Maxpulse  Calories      PulseRange
# 0         60  2020-12-01    110       130     409.1  (100.0, 110.0]
# 1         60  2020-12-02    117       145     479.0  (110.0, 120.0]
# 2         60  2020-12-03    103       135     340.0  (100.0, 110.0]
# 3         45  2020-12-04    109       175     282.4  (100.0, 110.0]
# 4         45  2020-12-05    117       148     406.0  (110.0, 120.0]
# 5         60  2020-12-06    102       127     300.0  (100.0, 110.0]
# 6         60  2020-12-07    110       136     374.0  (100.0, 110.0]
# 8         30  2020-12-09    109       133     195.1  (100.0, 110.0]
# 9         60  2020-12-10     98       124     269.0             NaN
# ...

# %%
print(df.shape)
df.rename(columns={'Maxpulse':'MaxPulse'},inplace=True)
print(df.describe())
# Out:
# (30, 6)
#         Duration       Pulse    MaxPulse    Calories
# count  30.000000   30.000000   30.000000   30.000000
# mean   56.000000  103.600000  128.600000  296.546667
# std     7.812457    8.071235   13.306985   78.745858
# min    30.000000   90.000000  101.000000  130.000000
# 25%    60.000000  100.000000  120.000000  247.000000
# 50%    60.000000  102.500000  127.500000  291.200000
# 75%    60.000000  107.500000  132.000000  343.975000
# max    60.000000  130.000000  175.000000  479.000000

# %%
#str.upper , str.lower,str.title
merged_df['Trainer']=merged_df['Trainer'].str.lower()
print(merged_df)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories Trainer
# 0         60  2020-12-01    110       130     409.1    alex
# 1         60  2020-12-02    117       145     479.0  jordan
# 2         60  2020-12-03    103       135     340.0  taylor
# 3         45  2020-12-04    109       175     282.4     NaN
# 4         45  2020-12-05    117       148     406.0     NaN
# 5         60  2020-12-06    102       127     300.0     NaN
# 6         60  2020-12-07    110       136     374.0     NaN
# 7         30  2020-12-09    109       133     195.1     NaN
# 8         60  2020-12-10     98       124     269.0     NaN
# 9         60  2020-12-11    103       147     329.3     NaN
# 10        60  2020-12-12    100       120     250.7     NaN
# 11        60  2020-12-13    106       128     345.3     NaN
# 12        60  2020-12-14    104       132     379.3     NaN
# 13        60  2020-12-15     98       123     275.0     NaN
# 14        60  2020-12-16     98       120     215.2     NaN
# ...

# %% [markdown]
# “E-Commerce Transaction Analytics” (Using Online Retail Dataset)
# 🎯 Scenario / Story
# You are a data analyst at ShopWave, an e-commerce platform in the UK. ShopWave logs every transaction (order) made in their store. Each record has:
# Invoice number
# Stock code / product ID
# Description
# Quantity
# Invoice date
# Unit price
# Customer ID
# Country
#
# Your manager wants you to clean the data, fix inconsistencies, derive business metrics, and explore relationships. The cleaned data should enable deeper dashboards later.
#
# Tasks & Steps
# Below is a full pipeline of tasks that students should perform. Each task corresponds to one or more of the functions/techniques you already taught.
# Load & Inspect
# Read the CSV (e.g. OnlineRetail.csv)
# Display head(), tail(), info(), shape
# Check dtypes
# Missing Data Handling
# Use isnull().sum() to find missing values (e.g. some Description or Customer ID missing)
# Drop rows that have missing Customer ID (because you can’t tie to a customer)
# Fill missing Description or other columns using a placeholder (e.g. "Unknown")
# Date Parsing / Format Correction
# The InvoiceDate column might be string. Convert using pd.to_datetime(..., format='mixed')
# Drop records where parsing failed (if any)
# Detect & Fix Bad or Outlier Data
# Some transactions might have negative quantity (returns) — detect those and decide whether to treat as returns or drop
# Some unit prices might be zero or negative — fix/clean these (e.g. drop or adjust)
# Duplicates
# Use duplicated() to find duplicated invoice-item entries
# Drop duplicates

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("OnlineRetail.csv", encoding='ISO-8859-1')

print("===== Data Head =====")
print(df.head())

print("\n===== Data Tail =====")
print(df.tail())

print("\n===== Data Info =====")
print(df.info())

print("\n===== Data Shape =====")
print(df.shape)

print("\n===== Data Types =====")
print(df.dtypes)

print("\n===== Missing Values =====")
print(df.isnull().sum())

df = df.dropna(subset=['CustomerID'])
df['Description'] = df['Description'].fillna('Unknown')

df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], errors='coerce')
df = df.dropna(subset=['InvoiceDate'])

returns = df[df['Quantity'] < 0]
print("\nNumber of return transactions:", len(returns))
df = df[df['Quantity'] > 0]

bad_prices = df[df['UnitPrice'] <= 0]
print("\nNumber of transactions with bad unit price:", len(bad_prices))
df = df[df['UnitPrice'] > 0]

duplicates = df.duplicated()
print("\nNumber of duplicate rows:", duplicates.sum())
df = df.drop_duplicates()

df['TotalPrice'] = df['Quantity'] * df['UnitPrice']
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month
df['Day'] = df['InvoiceDate'].dt.day

customer_summary = df.groupby('CustomerID').agg({
    'InvoiceNo': 'nunique',
    'TotalPrice': 'sum'
}).rename(columns={'InvoiceNo':'NumOrders', 'TotalPrice':'TotalSpend'}).reset_index()

print("\nCustomer Summary Head:")
print(customer_summary.head())

df.to_csv("OnlineRetail_Cleaned.csv", index=False)
print("\nCleaned data saved to 'OnlineRetail_Cleaned.csv'")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2103113803.py in <cell line: 0>()
#       2 import numpy as np
#       3
# ----> 4 df = pd.read_csv("OnlineRetail.csv", encoding='ISO-8859-1')
#       5
#       6 print("===== Data Head =====")
#
# ...
